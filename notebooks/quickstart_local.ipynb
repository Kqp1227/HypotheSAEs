# %% [markdown]
# # HypotheSAEs Quickstart: Local
#
# This notebook demonstrates basic usage of HypotheSAEs on a sample of the Yelp review dataset, entirely using local compute. You will need a GPU*.
# - We use a sentence-transformers model for text embeddings. This can run on CPU or GPU (if a cuda device is available, it will use GPU).
# - We use a large language model loaded in vLLM for hypothesis generation and text annotation. This requires GPU.
# - This notebook uses `Qwen/Qwen3-32B-AWQ`. (If your GPU doesn't support this model or have enough memory, you can use a different model.)
# - Takes about 80 minutes to run using an NVIDIA A6000. The slowest step is hypothesis evaluation on the heldout set, which requires lots of LLM annotation.
#
# *It's possible you can get some smaller LLMs to run on CPU, perhaps with some modifications to the vLLM config, but it's not tested.

# %%
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2



import os
os.environ['CUDA_VISIBLE_DEVICES'] = '6' # Use single GPU to avoid distributed training issues

import numpy as np
import pandas as pd

from hypothesaes.quickstart import train_sae, interpret_sae, generate_hypotheses, evaluate_hypotheses
from hypothesaes.embedding import get_local_embeddings
from hypothesaes.llm_local import get_vllm_engine

# %% [markdown]
# **0. Load data**
#
# The dataset we're using here is a subset of 20K Yelp reviews, with 2K reviews used for validation (during SAE training).
#
# The target variable is the `stars` column, which is a rating between 1 and 5. We treat this as a regression task.
#
# There are also 2K reviews used for holdout evaluation, which we'll use at the end of the notebook.

# %%
current_dir = os.getcwd()
if current_dir.endswith("notebooks"):
    prefix = "../"
else:
    prefix = "./"

base_dir = os.path.join(prefix, "demo_data")
train_df = pd.read_json(os.path.join(base_dir, "yelp-demo-train-20K.json"), lines=True)
val_df = pd.read_json(os.path.join(base_dir, "yelp-demo-val-2K.json"), lines=True)

texts = train_df['text'].tolist()
labels = train_df['stars'].values
val_texts = val_df['text'].tolist() # These are only used for early stopping of SAE training, so we don't need labels.

# %% [markdown]
# **1. Compute text embeddings for your dataset**
#
# We'll compute text embeddings for a training set, and optionally a validation set. The validation embeddings are used for SAE eval and early-stopping during training.
#
# Embeddings will be stored in the `emb_cache` directory (or `os.environ["EMB_CACHE_DIR"]` if you set it) using the `cache_name` parameter, so you only need to compute embeddings once.
#
# We will compute embeddings using a good sentence-transformers model, `nomic-ai/modernbert-embed-base` (smaller models like `sentence-transformers/all-roberta-large-v1` should also work well, and may fit on GPUs with less memory).

# %%
EMBEDDER = "nomic-ai/modernbert-embed-base"
CACHE_NAME = f"yelp_quickstart_local_{EMBEDDER}"

text2embedding = get_local_embeddings(texts + val_texts, model=EMBEDDER, batch_size=128, cache_name=CACHE_NAME)
embeddings = np.stack([text2embedding[text] for text in texts])

train_embeddings = np.stack([text2embedding[text] for text in texts])
val_embeddings = np.stack([text2embedding[text] for text in val_texts])
# Out:
# Loading embedding chunks:   0%|          | 0/1 [00:00<?, ?it/s]
# Loaded 22000 embeddings in 0.1s

# %% [markdown]
# **2. Train SAE**
#
# We will train a Matryoshka SAE with $M=256$, $k=8$, and $\text{prefix\_lengths} = [32, 256]$.
#
# With the Matryoshka loss, the SAE will learn to reconstruct the input from (1) just the first 32 neurons, and (2) all 256 neurons.
# This will produce 32 coarse-grained features, and 224 finer-grained features.
#
# See the README for more details about selecting SAE hyperparameters.

# %%
checkpoint_dir = os.path.join(prefix, "checkpoints", CACHE_NAME)
sae = train_sae(embeddings=train_embeddings, M=256, K=8, matryoshka_prefix_lengths=[32, 256], checkpoint_dir=checkpoint_dir, val_embeddings=val_embeddings)
# Out:
# Loaded model from ../checkpoints/yelp_quickstart_local_nomic-ai/modernbert-embed-base/SAE_matryoshka_M=256_K=8_prefixes=32-256.pt onto device cuda

# %% [markdown]
# **3. Interpret neurons**
#
# This step will load a local LLM in vLLM, and use it to interpret a few random neurons in the SAE.
# This is to ensure that the local LLM is working and the interpretations look reasonable, if not perfect.

# %%
'''
Some vLLM notes:
- When running in notebook, it's best to use the same interpreter and annotator model;
  this is because there is some memory overhead when switching models (ie we can't fully free GPU memory).
- We set `gpu_memory_utilization=0.85`, which avoids OOMs with Qwen3-32B-AWQ on an A6000.
  You may want to adjust this depending on your hardware/model.
- You can increase `tensor_parallel_size` to use multiple GPUs on the same node.
  See vLLM docs: https://docs.vllm.ai/en/latest/serving/distributed_serving.html
'''
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '5' 

INTERPRETER_MODEL = ANNOTATOR_MODEL = "Qwen/Qwen3-8B-AWQ"

engine = get_vllm_engine(
    INTERPRETER_MODEL, 
    gpu_memory_utilization=0.85,
    tensor_parallel_size=1,
)
# Out:
# Loading Qwen/Qwen3-8B-AWQ in vLLM...
# (EngineCore_0 pid=3031313) WARNING 09-06 16:25:21 [topk_topp_sampler.py:61] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# Loading safetensors checkpoint shards:   0% Completed | 0/2 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards:  50% Completed | 1/2 [00:02<00:02,  2.06s/it]
# Loading safetensors checkpoint shards: 100% Completed | 2/2 [00:02<00:00,  1.15s/it]
# Loading safetensors checkpoint shards: 100% Completed | 2/2 [00:02<00:00,  1.29s/it]
# (EngineCore_0 pid=3031313)
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE): 100%|██████████| 67/67 [00:05<00:00, 12.32it/s]
# Loaded Qwen/Qwen3-8B-AWQ with dtype: torch.float16 (took 45.9s)
# ERROR 09-06 16:53:46 [core_client.py:562] Engine core proc EngineCore_0 died unexpectedly, shutting down client.

# %%
# This instruction will be included in the neuron interpretation prompt.
# The below instructions are specific to Yelp, but you can customize this for your task.
# If you don't pass in task-specific instructions, there is a generic instruction (see src/interpret_neurons.py);
# task-specific instructions are optional, but they help produce hypotheses at the desired level of specificity.

TASK_SPECIFIC_INSTRUCTIONS = """All of the texts are reviews of restaurants on Yelp.
Features should describe a specific aspect of the review. For example:
- "mentions long wait times to receive service"
- "praises how a dish was cooked, with phrases like 'perfect medium-rare'\""""

# Interpret random neurons
results = interpret_sae(
    texts=texts,
    embeddings=train_embeddings,
    sae=sae,
    interpreter_model=INTERPRETER_MODEL,
    n_random_neurons=5,
    print_examples_n=3,
    task_specific_instructions=TASK_SPECIFIC_INSTRUCTIONS
)
# Out:
# Computing activations (batchsize=16384):   0%|          | 0/2 [00:00<?, ?it/s]
# Activations shape: (20000, 256)
# Adding requests:   0%|          | 0/5 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/5 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Neuron 229 (0.8% active, from SAE M=256, K=8): mentions freaky fast service
#
# Top activating examples:
# 1. The guys and gals of this Jimmy Johns location have literally saved my life.  Well, maybe that is a bit extreme, but they have saved me from missing lunch many times when I have gotten too busy at work to go out or forgot to bring my lunch.  When I realize that it is after noon and I don't have time to leave the office, I go online to jimmyjohns.com and order my trusty #12 Beach Club (cut in half... it's less messy).  Within 5 - 10 minutes, without fail, they are knocking on my office door with sandwich in hand.  They are truly "freaky fast".    The food is standard Jimmy Johns; it is consistently the same.  Their location and the speed of the service is what makes this Jimmy Johns stand out from other sandwich places in the area.
# 2. Jimmy Johns may be freaky fast, but I was freaky fast too as I plowed threw my Turkey Tom. Turkey, lettuce, tomato, alfalfa sprouts, and mayo. I added all of their freebies that weren't already in my subwich; onion, sliced cucumber, Dijon mustard, oil & vinegar, and oregano. It was as freaky good as it was freaky fast.   My Dad got their J.J. Gargantuan; Genoa salami, sliced smoked ham, Capicola, roast beef, turkey, provolone, onions, mayo, lettuce, tomato, & Italian dressing on their thick sliced 7 grain bread. It was freakin huge! Even the man who invented the clean plate club had a hard time putting this subwich away...I had to help =)   It's a lot of meat, almost too much for me. I couldn't really differentiate between which meat was which, there was so much flavor going on.   J.J's is really only good for subwich's, they don't have much other than that.
# 3. Jimmy John's is as freaky fast as they claim. I come here at least once a week. I prefer it over Subway, even though they don't offer as many choices as Subway and no hot subs. The bread is really fresh and the meat tastes better here than Subway's, although I wish they added more meat and cheese without the upcharge. I tend to order either  tuna, turkey or roast beef. All good but It would be nice if Mr John can equip his restaurants with salt and pepper. Is that too much to ask?   Service is very fast and friendly here. They typically greet you immediately and wish you a good day/night as you leave. They also have free bike delivery if you live or work around Ybor.  Pretty clean inside with outdoor tables with umbrellas. It's in the heart of Centro Ybor facing 7th Ave so a good place to chill while sipping on sweet tea, which is excellent by the way.  Oh, one other note...Read the signs scattered around the walls, they provide words of wisdom, humor and life advice.
# ----------------------------------------------------------------------------------------------------
#
# Neuron 236 (2.7% active, from SAE M=256, K=8): mentions the food quality as consistently amazing
#
# Top activating examples:
# 1. Eden is my favorite Korean restaurant in this area. It does get crowded real quick so it is always best to go early or make a reservation! The staff are super nice there and very attentive. When I eat at a Korean restaurant, I always love to see what banchans they offer. Here, if there's a particular banchan that you want, you can always ask for more. To start, I usually get the Kimbap or seafood pancake, both tastes amazing! For entree, I typically get the Bulgogi Dolsot Bibimbap! I love how it's served in the clay pot and you can hear the sizzle when it's served, then you have to quickly mix it unless you are like my husband, who enjoys eating the burnt crispy rice. I love how big of a portion it is and served with all sorts of veggies so I get my fair share of meat and vegetables. I love this restaurant and I'll definitely be back soon!
# 2. I'm a fan of Eds' pizza.  The one slice of pizza is about the size of 2 or 3 of normal pizzerias.  It is delicious.  I have had the cheesesteaks, they are good, but you have to ask for extras "cheese, mayo, salt/pepper etc. or they taste pretty plain. The wings are large and pretty tasty, they are fresh.  You have to ask for salt/pepper though.  The salads are huge, I especially like the tuna and grilled chicken.  The hoagies are fresh and they have all the toppings you would want, peppers, oregano, pickles etc.  My two quarrels with Eds, and why it lost two starts are 1-cleanliness- there are often flies in here and the windows are stained, the floors and tables are usually not clean either....#2 ordering time- if you order anything other than a hoagie or a salad (i.e., something cold) be prepared to wait...the waits are really long... Everyone must try at least one slice of their pizza though!!!
# 3. Good grief, so many people blasting E-Bar.  I've got great college memories getting sloshed at E-Bar, eating free happy hour grub, listening to live reggae music and watching planes land at the tiny podunk airport in its backyard.   Back in the day, before there were more than 2 or 3 Elephant Bars (that I know of), this was the place to be.  Yeah, yeah, the food is not great, but its good enough.  I also sold their corporate office like 100  shirts from Eddie Bauer (the one that used to be in La Cumbre Plaza) and my manager stole my sale!
# ----------------------------------------------------------------------------------------------------
#
# Neuron 216 (3.3% active, from SAE M=256, K=8): mentions dirty or filthy conditions in the establishment
#
# Top activating examples:
# 1. Oh my, oh my.  I have never been to a restaurant that the toilets were so dirty.  I'm not sure but this is probably the one and only time that I will come here.
# 2. This place was dirty and smelled funny. It could have been because the toilets weren't working properly. It made me wonder if the bathrooms aren't up to snuff, how maintained is the kitchen. This turned me off and my party and I left the restaurant.
# 3. Surprisingly, this place is clean even the bathroom. It gives me a vintage but yet  classy vibe.  I really wasn't expecting this. But im a satisfied customer. From the front desk, public bathroom and the hotel hallway very clean. This was a last minute trip and reservation on top of that.
# ----------------------------------------------------------------------------------------------------
#
# Neuron 186 (0.9% active, from SAE M=256, K=8): mentions the staff's friendliness and helpfulness in handling special orders without issues
#
# Top activating examples:
# 1. This is a large super Wawa located on route 30 in Barrington. It's on the east side of 295 and on the south side of Route 30. It is your classic super Wawa with the big store and many pumps.  However you cannot enter from route 30.   The entrance driveway is actually located behind the store. There's a service road that you have to turn into either right before or right after the store itself. Very strange but it works. This is probably why the gas here was five cents cheaper than the other super Wawas in the area.
# 2. I do have to say that if I'm on the go, I do prefer to get my gas at a Wawa than any other place just because the pumps seem to be spaced out and clean.  If we go inside the locations are usually kept clean as well.  Gas is typically priced well compared to others around.
# 3. Love all Wawas as a South Jerseyan, but this is my home-base store that I pass on my way to work, so it has a special place in my heart.  Workers in the store and at the gas pumps are cheerful, friendly, and helpful. There is a big morning rush around the time I head into work (7:30-7:45), but they have all hands on deck to try to accommodate all of the un-caffeinated commuters.  Store is always clean, and there's plenty of parking. For me, this is always a go-to stop when I begin a road trip.
# ----------------------------------------------------------------------------------------------------
#
# Neuron 76 (1.2% active, from SAE M=256, K=8): mentions server not available when customers need assistance
#
# Top activating examples:
# 1. My husband and I ate here and we split 3 different sausages. The waiter was nice and cut them in half and put them on a plate together to make it easier to share. However I noticed we only got 1 portion of chips, even though we ordered 3 sausages. I thought oh well maybe we'll get a few dollars off the price or something. No we got charged the full amount. We didn't say anything cause we didn't want to bother our waiter and maybe we didn't want them to bring out a huge amount of chips and charge us if we asked. But still,  if you're paying for a meal you should get everything it includes. Luckily one of our friends that ate with us didn't want his chips so I ate some of his. Next time if we go back we will order each meal separately and just cut them in half ourselves. Their prices are a little bit high also.
# 2. Had dinner there last night - the service was atrocious.  The waiter disappeared several times - it took over 30 minutes to order the first drinks - and he forgot one person and didn't come back.  We had to ask for bread as we had a child that was starving and that took another 10 minutes (so 40 minutes and we still didn't have appetizers).  The crab bisque had a skin on the top as it had clearly been sitting under heat lights for some time.  The waiter came to tell me that they were out of snapper and then after giving me the menu to select something else - never came back to ask me what I wanted.  The mac and cheese looked like it was made last week and the crab cakes were alright but nothing spectacular.  Used to be much better - seems to have gone down hill significantly.
# 3. I went the other night for dinner with some friends. The place was busy but not overly crowded. The service was terrible. Bar rescue should come into this restaurant and help them out. We ordered a pitcher of margaritas which took 45 minutes to receive. We also asked what the price would be for a pitcher since it was not advertised anywhere. Our server said she would let us know, but never did. When the food arrived we ordered nachos, and guacamole as an appetizer. The guacamole came with an embarrassing amount of 10 chips. We had to ask multiple times for more chips which took over 15 minutes to receive. When the entrees came out, we had to send a couple dishes back. Our server was apologetic and said sometimes the kitchen messes up a meal and said she would be right back to get another dish on the menu. She never came back... When we got the bill we were charged $65 for a pitcher of college grade tequila! Not to mention that the dishes we sent back to the kitchen were still on our bill.   Save your time and[... rest of text is truncated]
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# **4. Generate hypotheses**
#
# Generate hypotheses which are predictive of the target variable.
#
# We use the local LLM to generate interpretations and then estimate each interpretation's fidelity by annotating texts with the interpretation.
#
# Here, we select neurons after ranking them by correlation with the target variable. See `src/select_neurons.py` for more details and other selection methods (e.g., Lasso).
#
# This cell outputs a dataframe with the following columns:
# - `neuron_idx`: The index of the neuron in the SAE (if you're using multiple SAEs, this will be a global index across all of them).
# - `source_sae`: The SAE that the neuron was selected from.
# - `target_{selection_method}`: The predictiveness of the neuron for the target variable, using the selected `selection_method`.
# - `interpretation`: The natural language interpretation of the neuron.
# - `interp_fidelity_score`: The F1 fidelity score for how well the neuron's interpretation actually corresponds to its activation pattern.

# %%
selection_method = "correlation"
results = generate_hypotheses(
    texts=texts,
    labels=labels,
    embeddings=embeddings,
    sae=sae,
    interpreter_model=INTERPRETER_MODEL,
    annotator_model=ANNOTATOR_MODEL,
    selection_method=selection_method,
    n_selected_neurons=20,
    n_candidate_interpretations=1,
    task_specific_instructions=TASK_SPECIFIC_INSTRUCTIONS
)

print("\nMost predictive features of Yelp reviews:")
pd.set_option('display.max_colwidth', None)
display(results.sort_values(by=f"target_{selection_method}", ascending=False))
pd.reset_option('display.max_colwidth')
# Out:
# Embeddings shape: (20000, 768)
# Computing activations (batchsize=16384):   0%|          | 0/2 [00:00<?, ?it/s]
# Activations shape: (20000, 256)
#
# Step 1: Selecting top 20 predictive neurons
#
# Step 2: Interpreting selected neurons
# Adding requests:   0%|          | 0/20 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/20 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Step 3: Scoring Interpretations
# Found 0 cached items; annotating 1800 uncached items
# Adding requests:   0%|          | 0/1800 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1800 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s…
# Most predictive features of Yelp reviews:
#     neuron_idx       source_sae  target_correlation  \
# 4           13  (SAE_0, 256, 8)            0.257274
# 6            8  (SAE_0, 256, 8)            0.225583
# 7           25  (SAE_0, 256, 8)            0.202389
# 14          22  (SAE_0, 256, 8)            0.125264
# 16         227  (SAE_0, 256, 8)            0.117041
# 17          32  (SAE_0, 256, 8)            0.116819
# 19         148  (SAE_0, 256, 8)            0.114213
# 18         155  (SAE_0, 256, 8)           -0.116472
# 15           2  (SAE_0, 256, 8)           -0.120087
# 13         235  (SAE_0, 256, 8)           -0.125729
# 12          10  (SAE_0, 256, 8)           -0.126198
# 11          41  (SAE_0, 256, 8)           -0.126220
# 10         146  (SAE_0, 256, 8)           -0.133386
# 9          214  (SAE_0, 256, 8)           -0.145459
# 8            1  (SAE_0, 256, 8)           -0.156218
# 5           31  (SAE_0, 256, 8)           -0.235903
# 3            4  (SAE_0, 256, 8)           -0.275034
# 2            6  (SAE_0, 256, 8)           -0.334050
# 1           30  (SAE_0, 256, 8)           -0.501844
# 0           12  (SAE_0, 256, 8)           -0.722201
#
#                                                                                                                                                   interpretation  \
# 4                                                                          mentions specific servers by name and praises their exceptional, personalized service
# 6                                                                                                            mentions the staff being knowledgeable and friendly
# 7                                                                                                     mentions the food is consistently good and of high quality
# 14                                                  mentions specific sensory details (texture, flavor, taste) with positive adjectives describing their quality
# 16                                                                                                                             mentions the food being excellent
# 17                                                                                                             mentions specific dishes with positive adjectives
# 19  describes food with specific sensory adjectives indicating exceptional quality, such as 'crispy,' 'spicy,' 'melting in your mouth,' or 'perfect medium-rare'
# 18                                                                                                           mentions inability to reach the restaurant by phone
# 15                                                            mentions prices that are disproportionately high compared to the food quality or quantity received
# 13                                                                                                                                                          None
# 12                                                                                                                                     mentions delivery failure
# 11                                                             mentions symptoms of illness such as nausea, cramping, or diarrhea after eating at the restaurant
# 10                                                                                                                                 mentions poor service quality
# 9                                                                                                       mentions rude or disrespectful behavior by staff members
# 8                                   mentions the food being of high quality with specific positive descriptors such as 'flavorful' or 'fall-off-the-bone tender'
# 5                                                                                                                    mentions long wait times to receive service
# 3                                                                                                      mentions the food not being available or not as described
# 2                                                                                                                mentions the food being overrated for the price
# 1                                                                                                 mentions staff members being rude or unresponsive to customers
# 0                                                                                                                                                           None
#
#     f1_fidelity_score
# 4            0.484848
# 6            0.697714
# 7            0.720000
# 14           0.609836
# 16           0.530794
# 17           0.477460
# 19           0.302143
# 18           0.648649
# 15           0.856092
# 13           0.000000
# 12           0.550725
# 11           0.744304
# 10           0.726486
# 9            0.909890
# 8            0.143590
# 5            0.888889
# 3            0.936170
# 2            0.717368
# 1            0.949053
# 0            0.000000
# [rank0]:[W906 16:53:45.929885634 ProcessGroupNCCL.cpp:1479] Warning: WARNING: destroy_process_group() was not called before program exit, which can leak resources. For more info, please see https://pytorch.org/docs/stable/distributed.html#shutdown (function operator())
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# **5. Evaluate held-out generalization**
#
# Finally, we evaluate whether these are good hypotheses by testing whether their natural language interpretations can predict the target variable.
#
# We compute annotations for each hypothesized concept on a holdout set (not seen during SAE training & feature selection).
# This step uses the same local LLM as the one used to generate interpretations (though, for Qwen models, we set `enable_thinking=False` for annotation to improve speed).
#
# After annotation, we output a dataframe with the following columns:
# - `hypothesis`: The natural language hypothesis (which came from interpreting a predictive neuron in the SAE)
# - `separation_score`: How much the target variable differs when the concept is present vs. absent (i.e., $E[Y\mid\text{concept} = 1] - E[Y\mid\text{concept} = 0]$).
# - `separation_pvalue`: The t-test p-value of the null hypothesis that the separation score is 0 (i.e., the concept is not associated with the target variable).
# - `regression_coef`: The coefficient of the concept in a multivariate linear regression of the target variable on all concepts.
# - `regression_pval`: The p-value of the null hypothesis that the regression coefficient is 0.
# - `feature_prevalence`: The fraction of examples that contain the concept.
#
# Additionally, we output the evaluation metrics used in the paper:
# - Significant hypotheses: the number of hypotheses that are significant in the multivariate regression at a specified significance level (default $0.1$) after Bonferroni correction. You can pass in a different significance level using the `corrected_pval_threshold` parameter.
# - AUC or $R^2$: how well the hypotheses collectively predict the target variable in the multivariate regression.

# %%
holdout_df = pd.read_json(os.path.join(base_dir, "yelp-demo-holdout-2K.json"), lines=True)
holdout_texts = holdout_df['text'].tolist()
holdout_labels = holdout_df['stars'].values

metrics, evaluation_df = evaluate_hypotheses(
    hypotheses_df=results,
    texts=holdout_texts,
    labels=holdout_labels,
    annotator_model=ANNOTATOR_MODEL,
)

pd.set_option('display.max_colwidth', None)
display(evaluation_df)
pd.reset_option('display.max_colwidth')

print("\nHoldout Set Metrics:")
print(f"R² Score: {metrics['r2']:.3f}")
print(f"Significant hypotheses: {metrics['Significant'][0]}/{metrics['Significant'][1]} " 
      f"(p < {metrics['Significant'][2]:.3e})")
# Out:
# Step 1: Annotating texts with 20 hypotheses
# Found 0 cached items; annotating 40000 uncached items
# Adding requests:   0%|          | 0/40000 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/40000 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/…
# Step 2: Computing predictiveness of hypothesis annotations
#                                                                                                                                                                                                                       hypothesis  \
# 6                                                         expresses that the food is the best they've ever had, using superlatives like 'best ever,' 'epic,' 'unbelievable,' or 'out of this world' to describe the food quality
# 11                                                                                                                          mentions specific dishes and praises their preparation, taste, or texture with detailed descriptions
# 5                                                                           uses hyperbolic superlatives (e.g., 'BEYOND AMAZING', 'PERFECT', 'FABULOUS') paired with multiple exclamation points to express extreme satisfaction
# 15                                                                   mentions exceptional service quality and attention to detail, using phrases like 'outstanding service,' 'professional service,' or 'culture of hospitality'
# 16                                                                                                                                 mentions friendly and attentive staff who check on customers or ensure they are taken care of
# 17                                                                             mentions frequent visits and strong cravings for the food, using phrases like 'at least once a week,' 'crave this place,' or 'every time I visit'
# 18                                                                                            mentions that the restaurant is considered the best in a specific geographic area or category and compares it to other restaurants
# 12                                                                                                                                             mentions automatic gratuity or hidden fees added to the bill without prior notice
# 2                                                                                                                                                                            mentions long wait times to receive service or food
# 9                                                                                                                    mentions specific criticisms of food quality, such as dishes being bland, under-seasoned, or lacking flavor
# 4                                                                            mentions food being described with negative adjectives such as 'bland', 'tasteless', 'overcooked', 'soggy', 'freezer burnt', 'terrible', or 'nasty'
# 14  mentions receiving food that was different from what was ordered, including incorrect items, wrong preparation, or insufficient portions, or the restaurant refusing to accommodate specific dietary or preparation requests
# 7                                                                                                                                                                         complains about order being incorrect or missing items
# 19                                                                           mentions problems with online ordering or delivery services, including incorrect orders, lack of communication, or poor customer service resolution
# 3                                     mentions employees engaging in harassing, offensive, or discriminatory behavior toward customers, such as making inappropriate comments, following customers, or enforcing unfair policies
# 13                                                                                         mentions being denied seating despite available tables or encountering unfair seating policies and uncomfortable seating arrangements
# 10                                                                                                                              mentions staff members being rude, obnoxious, or aggressive in their interactions with customers
# 8                                                                                             mentions presence of insects (e.g., roaches, flies, stink bugs) in food or dining area, or reports illness from food safety issues
# 0                                                                                                           mentions negative service experiences including long wait times, incorrect orders, rude staff, or unclean conditions
# 1                                                                                                          mentions severe service failures such as incorrect orders, rude or dishonest staff, and failure to resolve complaints
#
#     separation_score  separation_pval  regression_coef  regression_pval  \
# 6           1.100535     1.972704e-34         0.307047     8.053908e-07
# 11          1.086586     6.844723e-73         0.420917     5.429902e-24
# 5           1.058716     7.385799e-16         0.201603     1.638637e-02
# 15          0.986522     2.255149e-23         0.266751     7.200962e-05
# 16          0.891304     7.406501e-37         0.222345     5.317346e-06
# 17          0.631096     2.969104e-07         0.235836     2.015711e-03
# 18          0.612500     1.665475e-10         0.086565     1.632675e-01
# 12         -1.048585     7.066972e-03         0.002354     9.921679e-01
# 2          -1.104529     1.829027e-34         0.089186     1.712972e-01
# 9          -1.770692    1.791816e-108        -0.576484     5.839361e-12
# 4          -1.918438    5.655564e-137        -0.687852     1.241400e-16
# 14         -1.952467     4.508897e-95        -0.089097     2.954976e-01
# 7          -2.061927     4.213056e-86        -0.006178     9.508971e-01
# 19         -2.147913     9.666171e-73        -0.396915     7.522073e-05
# 3          -2.159623     3.121173e-26        -0.314336     3.537886e-02
# 13         -2.187547     3.575523e-17        -0.595058     3.384593e-04
# 10         -2.204947     7.716214e-66        -0.111474     3.090632e-01
# 8          -2.301148     1.153994e-11        -0.149170     4.879829e-01
# 0          -2.341529    3.263651e-242        -1.078050     1.035188e-38
# 1          -2.577711    2.228003e-190        -0.670718     1.255856e-11
#
#     feature_prevalence
# 6               0.1350
# 11              0.4865
# 5               0.0595
# 15              0.1095
# 16              0.2565
# 17              0.0690
# 18              0.1200
# 12              0.0065
# 2               0.1340
# 9               0.1620
# 4               0.1715
# 14              0.1115
# 7               0.0890
# 19              0.0685
# 3               0.0235
# 13              0.0145
# 10              0.0585
# 8               0.0085
# 0               0.1865
# 1               0.1175
# Holdout Set Metrics:
# R² Score: 0.635
# Significant hypotheses: 11/20 (p < 5.000e-03)
